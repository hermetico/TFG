# %%
import sys, os
import numpy as np
import time
import matplotlib.pyplot as plt
# %matplotlib notebook
import tempfile
# this file should be run from {caffe_root}/examples (otherwise change this line)
caffe_root = '/media/hermetico/2TB/frameworks/caffe/' 
this_root = os.path.abspath('.')


activities_net_desc = {
    'weights': os.path.join(this_root,'models/scratch-googlenet/reference_activitiesnet.caffemodel'),
    'train_val': os.path.join(this_root,'models/scratch-googlenet/train_val.prototxt'),
    'solver': os.path.join(this_root,'models/scratch-googlenet/solver.prototxt'), 
    'snapshot' :os.path.join(this_root,'models/scratch-googlenet/finetune_dailyactivities')
}

sys.path.insert(0, caffe_root + 'python')
import caffe
caffe.set_device(0)
caffe.set_mode_gpu()
# Out:
# /home/hermetico/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /media/hermetico/2TB/frameworks/caffe/python/caffe/pycaffe.py:13: RuntimeWarning: to-Python converter for boost::shared_ptr<caffe::Net<float> > already registered; second conversion method ignored.
#   from ._caffe import Net, SGDSolver, NesterovSolver, AdaGradSolver, \
# /media/hermetico/2TB/frameworks/caffe/python/caffe/pycaffe.py:13: RuntimeWarning: to-Python converter for boost::shared_ptr<caffe::Blob<float> > already registered; second conversion method ignored.
#   from ._caffe import Net, SGDSolver, NesterovSolver, AdaGradSolver, \
# /media/hermetico/2TB/frameworks/caffe/python/caffe/pycaffe.py:13: RuntimeWarning: to-Python converter for boost::shared_ptr<caffe::Solver<float> > already registered; second conversion method ignored.
#   from ._caffe import Net, SGDSolver, NesterovSolver, AdaGradSolver, \

# %% [markdown]
# we load all needed stuff, datasets,blalblal

# %%
# dataset stuff
train_dataset_path = os.path.join(caffe_root, 'data/daily_activities/train.txt')
val_dataset_path = os.path.join(caffe_root, 'data/daily_activities/val.txt')


labels_set = os.path.join(caffe_root, 'data/daily_activities/labels.txt')


labels_set = list(np.loadtxt(labels_set, str, delimiter='\n'))

train_dataset = [ line.split(' ') 
                for line in list(np.loadtxt(train_dataset_path, str, delimiter='\n'))
                if len(line.split(' ')) == 2 # there are some images with wierd paths
               ]
train_paths, train_labels = zip(*[(path, int(label)) for path, label in train_dataset])

val_dataset = [ line.split(' ') 
                for line in list(np.loadtxt(val_dataset_path, str, delimiter='\n'))
                if len(line.split(' ')) == 2 # there are some images with wierd paths
               ]
val_paths, val_labels = zip(*[(path, int(label)) for path, label in val_dataset])



num_train_images = len(train_paths)
num_val_images = len(val_paths)
NUM_ACTIVITIES_LABELS = len(labels_set)
print 'Loaded labels:\n', ', '.join(labels_set)
print '\nTraining pictures', num_train_images
print '\nValidation pictures', num_val_images
# Out:
# Loaded labels:
# Public transport, driving, walking outdoor, walking indoor, biking, having drinks with somebody, having drinks/meal alone, having meal with somebody, socializing, attending a seminar, meeting, reading, tv, cleaning and chores, working, cooking, shopping, talking, resting, mobile, Plane
#
# Training pictures 13991
#
# Validation pictures 1857

# %%
# train an val histogram
def plot_hist( set_labels , title='', color='blue'):
    examples = [0] * NUM_ACTIVITIES_LABELS
    # each index index paths will contain a list of  pictures associated to a category
    for label in set_labels:
        examples[label] += 1

    y_pos = np.arange(NUM_ACTIVITIES_LABELS)
    num_examples = examples
    plt.barh(y_pos, num_examples,  alpha=1, color=color)
    plt.yticks(y_pos, labels_set)
    plt.xlabel('Number of pictures')
    plt.title('List of categories and number of pictures for validation and training')
    plt.show()
    
plot_hist(train_labels, 'Training')
plot_hist(val_labels, 'val', color='yellow')
# Out:
# <img src="data:image/png;base64,...">

# %%
def store_weights(weights):
    data = open(weights).read()
    with open(activities_net_desc['weights'], 'w') as f:
        f.write(data)
        
def store_solver(solver):
    with open(activities_net_desc['solver'], 'w') as f:
        f.write(solver)

# %% [markdown]
# Here we are going to define the solver file, as caffe does not allow us to define the num of epochs we want to train, we are going to define the number of iterations based on the number of epochs we want

# %%
# We are going to train 20 epochs, which means that we are going to go through our dataset 20 times
num_train = num_train_images
num_val = num_val_images
num_epochs = 30
# batch size 32 takes around 4GB 
# if the model doesn't fit in GPU memory, try to reduce the batch size to 24. 
# that needs to be changed in train_val.prototxt too
batch_size = 32 
iters_per_epoch = num_train_images / batch_size # iterations for an epoch
iters_per_val = num_val_images / batch_size


### solver data definition

solver_data = {}
solver_data['val_iter'] = iters_per_val  /  5              # num of iterations for the validation
solver_data['val_interval'] = iters_per_epoch / 4      # we are going to validate twice per epoch
solver_data['base_lr'] = 0.0001                        # initial learning rate
solver_data['display_interval'] = solver_data['val_interval'] / 4
solver_data['num_iter'] = num_epochs * iters_per_epoch # total iterations
solver_data['drop_rate'] = 0.001
solver_data['drop_lr_step'] = 10 * iters_per_epoch      # The learning rate will decrease each 5 epochs
solver_data['train_val'] = activities_net_desc['train_val']
solver_data['snapshot_prefix'] = activities_net_desc['snapshot']
solver_data['snapshot'] = 5 * iters_per_epoch
    

#### SOLVER DEFINITION
solver_content = """test_iter: %(val_iter)i
test_interval: %(val_interval)i
base_lr: %(base_lr).5f
display: %(display_interval)i
max_iter: %(num_iter)i
lr_policy: "step"
gamma: %(drop_rate).5f
momentum: 0.9
weight_decay: 0.005
stepsize: %(drop_lr_step)i
snapshot: %(snapshot)i
snapshot_prefix: "%(snapshot_prefix)s"
solver_mode: GPU
net: "%(train_val)s"
solver_type: SGD""" % (solver_data)

store_solver(solver_content)

print "This is the solver that is going to be used:"
print solver_content
# Out:
# This is the solver that is going to be used:
# test_iter: 11
# test_interval: 109
# base_lr: 0.00010
# display: 27
# max_iter: 13110
# lr_policy: "step"
# gamma: 0.00100
# momentum: 0.9
# weight_decay: 0.005
# stepsize: 4370
# snapshot: 2185
# snapshot_prefix: "/media/hermetico/2TB/frameworks/notebooks/TFG/dist/models/scratch-googlenet/finetune_dailyactivities"
# solver_mode: GPU
# net: "/media/hermetico/2TB/frameworks/notebooks/TFG/dist/models/scratch-googlenet/train_val.prototxt"
# solver_type: SGD

# %%
def run_solvers(niter, solver_data, disp_interval, validation_interval):
    # keep track of the data
    name, s = solver_data
    
    train_types = ('loss1/loss1', 'loss2/loss2', 'loss3/loss3')
    val_types = ('loss1/loss1', 'loss1/top-1',  'loss1/top-5',
                 'loss2/loss2', 'loss2/top-1',  'loss2/top-5',
                 'loss3/loss3', 'loss3/top-1',  'loss3/top-5'
                )
    
    train_data = {t:[0] for t in train_types}
    val_data = {t:[0] for t in val_types}
    
    train_iters = [0]
    val_iters = [0]
    
    
    fig, ax1 = plt.subplots(figsize=(10,7))
    ax2 = ax1.twinx()
    ax1.set_xlabel('iteration')
    ax1.set_ylabel('Loss')
    ax2.set_ylabel('Accuracy')
    

    a, = ax1.plot(train_iters, train_data['loss3/loss3'], 'blue', label='train loss 3')
    c, = ax1.plot(val_iters, val_data['loss3/loss3'], 'red', label='val loss 3')
    d, = ax2.plot(val_iters, val_data['loss3/top-1'], 'green', label='val loss 3 Top 1')
    f, = ax2.plot(val_iters, val_data['loss3/top-5'], 'orange', label='val loss 3 Top 5')
    
    plt.legend(handles=[a, c, d, f],bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)
    
    
    for iteration in range(niter):
        s.step(1)  
        
        
        if iteration % disp_interval == 0 or iteration % validation_interval == 0 :
            train_iters.append(iteration)
            train_data['loss3/loss3'].append( s.net.blobs['loss3/loss3'].data.copy() )
        
            ax1.plot(train_iters, train_data['loss3/loss3'], 'blue', label='train loss 3')
            
            
            if iteration % validation_interval == 0 : #or iteration == niter - 1: # interval step and last step

                val_iters.append(iteration)
                val_data['loss3/loss3'].append( s.test_nets[0].blobs['loss3/loss3'].data.copy() )
                val_data['loss3/top-1'].append( s.test_nets[0].blobs['loss3/top-1'].data.copy() )
                val_data['loss3/top-5'].append( s.test_nets[0].blobs['loss3/top-5'].data.copy() )

                ax1.plot(val_iters, val_data['loss3/loss3'], 'red', label='val loss 3')
                ax2.plot(val_iters, val_data['loss3/top-1'], 'green', label='val loss 3 Top 1')
                ax2.plot(val_iters, val_data['loss3/top-5'], 'orange', label='val loss 3 Top 5')

                print """
                # %i\t\t'train loss3/loss3': %.3f 'val loss3/loss3': %.3f 
                \t\t'loss3/top-1': %.3f 'loss3/top-5': %.3f""" % (
                    iteration, train_data['loss3/loss3'][-1], val_data['loss3/loss3'][-1],
                      val_data['loss3/top-1'][-1], val_data['loss3/top-5'][-1])

            fig.canvas.draw()
        
    # Save the learned weights
    weight_dir = tempfile.mkdtemp()
    
    filename = 'weights.%s.caffemodel' % name
    weights = os.path.join(weight_dir, filename)
    s.net.save(weights)
    #return data, weights
    return train_data, val_data, weights

# %%
activities_solver_filename = activities_net_desc['solver']

activities_solver = caffe.get_solver(activities_solver_filename)


print 'Running solver for %d iterations...' % solver_data['num_iter']

solver_desc = ('finetuning', activities_solver)

init = time.clock()

# runs the solver
train_data, val_data, finetuning_weights = run_solvers(
    solver_data['num_iter'], 
    solver_desc, 
    solver_data['display_interval'], 
    solver_data['val_interval'])

end = time.clock() - init
print "Traning done in %2.f s" %(end)

# deleting stuff to save memory
del activities_solver, solver_desc


store_weights(finetuning_weights)
# Out:
# Running solver for 13110 iterations...
# <img src="data:image/png;base64,...">
#                 0		'train loss3/loss3': 3.831 'val loss3/loss3': 3.512
#                 		'loss3/top-1': 0.031 'loss3/top-5': 0.250
#
#                 109		'train loss3/loss3': 3.163 'val loss3/loss3': 3.106
#                 		'loss3/top-1': 0.000 'loss3/top-5': 0.156
#
#                 218		'train loss3/loss3': 3.052 'val loss3/loss3': 2.925
#                 		'loss3/top-1': 0.094 'loss3/top-5': 0.312
#
#                 327		'train loss3/loss3': 3.006 'val loss3/loss3': 3.002
#                 		'loss3/top-1': 0.062 'loss3/top-5': 0.312
#
#                 436		'train loss3/loss3': 2.915 'val loss3/loss3': 2.978
#                 		'loss3/top-1': 0.000 'loss3/top-5': 0.281
#
#                 545		'train loss3/loss3': 2.939 'val loss3/loss3': 3.128
#                 		'loss3/top-1': 0.000 'loss3/top-5': 0.281
#
#                 654		'train loss3/loss3': 2.921 'val loss3/loss3': 2.921
#                 		'loss3/top-1': 0.000 'loss3/top-5': 0.344
#
#                 763		'train loss3/loss3': 2.864 'val loss3/loss3': 2.888
#                 		'loss3/top-1': 0.125 'loss3/top-5': 0.375
#
#                 872		'train loss3/loss3': 2.895 'val loss3/loss3': 2.868
#                 		'loss3/top-1': 0.031 'loss3/top-5': 0.531
#
#                 981		'train loss3/loss3': 2.790 'val loss3/loss3': 2.978
#                 		'loss3/top-1': 0.062 'loss3/top-5': 0.469
#
#                 1090		'train loss3/loss3': 2.800 'val loss3/loss3': 2.967
#                 		'loss3/top-1': 0.031 'loss3/top-5': 0.406
#
#                 1199		'train loss3/loss3': 2.801 'val loss3/loss3': 2.640
#                 		'loss3/top-1': 0.250 'loss3/top-5': 0.625
#
#                 1308		'train loss3/loss3': 2.681 'val loss3/loss3': 2.699
#                 		'loss3/top-1': 0.281 'loss3/top-5': 0.562
#
#                 1417		'train loss3/loss3': 2.571 'val loss3/loss3': 2.620
#                 		'loss3/top-1': 0.250 'loss3/top-5': 0.688
#
#                 1526		'train loss3/loss3': 2.598 'val loss3/loss3': 2.760
#                 		'loss3/top-1': 0.156 'loss3/top-5': 0.500
#
#                 1635		'train loss3/loss3': 2.372 'val loss3/loss3': 2.541
#                 		'loss3/top-1': 0.406 'loss3/top-5': 0.625
#
#                 1744		'train loss3/loss3': 2.533 'val loss3/loss3': 2.283
#                 		'loss3/top-1': 0.312 'loss3/top-5': 0.812
#
#                 1853		'train loss3/loss3': 2.309 'val loss3/loss3': 2.671
#                 		'loss3/top-1': 0.156 'loss3/top-5': 0.625
#
#                 1962		'train loss3/loss3': 2.434 'val loss3/loss3': 2.540
#                 		'loss3/top-1': 0.281 'loss3/top-5': 0.594
#
#                 2071		'train loss3/loss3': 2.111 'val loss3/loss3': 2.575
#                 		'loss3/top-1': 0.312 'loss3/top-5': 0.562
#
#                 2180		'train loss3/loss3': 2.237 'val loss3/loss3': 2.427
#                 		'loss3/top-1': 0.281 'loss3/top-5': 0.688
#
#                 2289		'train loss3/loss3': 2.019 'val loss3/loss3': 2.344
#                 		'loss3/top-1': 0.312 'loss3/top-5': 0.750
#
#                 2398		'train loss3/loss3': 2.080 'val loss3/loss3': 2.713
#                 		'loss3/top-1': 0.250 'loss3/top-5': 0.594
#
#                 2507		'train loss3/loss3': 1.854 'val loss3/loss3': 2.689
#                 		'loss3/top-1': 0.406 'loss3/top-5': 0.531
#
#                 2616		'train loss3/loss3': 1.571 'val loss3/loss3': 2.261
#                 		'loss3/top-1': 0.312 'loss3/top-5': 0.781
#
#                 2725		'train loss3/loss3': 1.694 'val loss3/loss3': 2.281
#                 		'loss3/top-1': 0.312 'loss3/top-5': 0.688
#
#                 2834		'train loss3/loss3': 1.714 'val loss3/loss3': 2.683
#                 		'loss3/top-1': 0.344 'loss3/top-5': 0.625
#
#                 2943		'train loss3/loss3': 1.375 'val loss3/loss3': 2.299
#                 		'loss3/top-1': 0.375 'loss3/top-5': 0.750
#
#                 3052		'train loss3/loss3': 1.873 'val loss3/loss3': 2.868
#                 		'loss3/top-1': 0.344 'loss3/top-5': 0.562
#
#                 3161		'train loss3/loss3': 1.657 'val loss3/loss3': 2.200
#                 		'loss3/top-1': 0.312 'loss3/top-5': 0.781
#
#                 3270		'train loss3/loss3': 1.286 'val loss3/loss3': 2.957
#                 		'loss3/top-1': 0.438 'loss3/top-5': 0.594
#
#                 3379		'train loss3/loss3': 1.697 'val loss3/loss3': 2.610
#                 		'loss3/top-1': 0.344 'loss3/top-5': 0.656
#
#                 3488		'train loss3/loss3': 1.449 'val loss3/loss3': 2.642
#                 		'loss3/top-1': 0.406 'loss3/top-5': 0.594
#
#                 3597		'train loss3/loss3': 1.137 'val loss3/loss3': 2.395
#                 		'loss3/top-1': 0.312 'loss3/top-5': 0.750
#
#                 3706		'train loss3/loss3': 1.248 'val loss3/loss3': 2.707
#                 		'loss3/top-1': 0.312 'loss3/top-5': 0.719
#
#                 3815		'train loss3/loss3': 0.857 'val loss3/loss3': 2.038
#                 		'loss3/top-1': 0.469 'loss3/top-5': 0.750
#
#                 3924		'train loss3/loss3': 0.951 'val loss3/loss3': 2.704
#                 		'loss3/top-1': 0.281 'loss3/top-5': 0.688
#
#                 4033		'train loss3/loss3': 1.426 'val loss3/loss3': 3.761
#                 		'loss3/top-1': 0.312 'loss3/top-5': 0.500
#
#                 4142		'train loss3/loss3': 0.878 'val loss3/loss3': 2.086
#                 		'loss3/top-1': 0.500 'loss3/top-5': 0.812
#
#                 4251		'train loss3/loss3': 1.227 'val loss3/loss3': 3.102
#                 		'loss3/top-1': 0.344 'loss3/top-5': 0.531
#
#                 4360		'train loss3/loss3': 0.902 'val loss3/loss3': 1.865
#                 		'loss3/top-1': 0.531 'loss3/top-5': 0.812
#
#                 4469		'train loss3/loss3': 5.002 'val loss3/loss3': 6.017
#                 		'loss3/top-1': 0.125 'loss3/top-5': 0.281
#
#                 4578		'train loss3/loss3': 2.320 'val loss3/loss3': 4.700
#                 		'loss3/top-1': 0.188 'loss3/top-5': 0.438
#
#                 4687		'train loss3/loss3': 1.411 'val loss3/loss3': 3.599
#                 		'loss3/top-1': 0.219 'loss3/top-5': 0.562
#
#                 4796		'train loss3/loss3': 1.507 'val loss3/loss3': 2.349
#                 		'loss3/top-1': 0.375 'loss3/top-5': 0.719
#
#                 4905		'train loss3/loss3': 1.003 'val loss3/loss3': 2.655
#                 		'loss3/top-1': 0.438 'loss3/top-5': 0.719
#
#                 5014		'train loss3/loss3': 0.838 'val loss3/loss3': 3.026
#                 		'loss3/top-1': 0.344 'loss3/top-5': 0.625
#
#                 5123		'train loss3/loss3': 0.775 'val loss3/loss3': 2.867
#                 		'loss3/top-1': 0.375 'loss3/top-5': 0.625
#
#                 5232		'train loss3/loss3': 0.736 'val loss3/loss3': 2.585
#                 		'loss3/top-1': 0.406 'loss3/top-5': 0.688
#
#                 5341		'train loss3/loss3': 0.920 'val loss3/loss3': 2.080
#                 		'loss3/top-1': 0.469 'loss3/top-5': 0.750
#
#                 5450		'train loss3/loss3': 0.924 'val loss3/loss3': 2.995
#                 		'loss3/top-1': 0.438 'loss3/top-5': 0.625
#
#                 5559		'train loss3/loss3': 0.986 'val loss3/loss3': 2.232
#                 		'loss3/top-1': 0.469 'loss3/top-5': 0.781
#
#                 5668		'train loss3/loss3': 0.992 'val loss3/loss3': 2.974
#                 		'loss3/top-1': 0.375 'loss3/top-5': 0.656
#
#                 5777		'train loss3/loss3': 0.928 'val loss3/loss3': 1.850
#                 		'loss3/top-1': 0.562 'loss3/top-5': 0.781
#
#                 5886		'train loss3/loss3': 1.081 'val loss3/loss3': 2.540
#                 		'loss3/top-1': 0.469 'loss3/top-5': 0.688
#
#                 5995		'train loss3/loss3': 0.922 'val loss3/loss3': 2.888
#                 		'loss3/top-1': 0.312 'loss3/top-5': 0.688
#
#                 6104		'train loss3/loss3': 0.673 'val loss3/loss3': 2.649
#                 		'loss3/top-1': 0.406 'loss3/top-5': 0.656
#
#                 6213		'train loss3/loss3': 1.114 'val loss3/loss3': 2.306
#                 		'loss3/top-1': 0.531 'loss3/top-5': 0.750
#
#                 6322		'train loss3/loss3': 0.920 'val loss3/loss3': 2.744
#                 		'loss3/top-1': 0.406 'loss3/top-5': 0.656
#
#                 6431		'train loss3/loss3': 0.581 'val loss3/loss3': 2.881
#                 		'loss3/top-1': 0.312 'loss3/top-5': 0.688
#
#                 6540		'train loss3/loss3': 1.004 'val loss3/loss3': 2.095
#                 		'loss3/top-1': 0.469 'loss3/top-5': 0.750
#
#                 6649		'train loss3/loss3': 0.788 'val loss3/loss3': 2.920
#                 		'loss3/top-1': 0.406 'loss3/top-5': 0.656
#
#                 6758		'train loss3/loss3': 0.721 'val loss3/loss3': 2.098
#                 		'loss3/top-1': 0.500 'loss3/top-5': 0.750
#
#                 6867		'train loss3/loss3': 0.647 'val loss3/loss3': 3.014
#                 		'loss3/top-1': 0.438 'loss3/top-5': 0.594
#
#                 6976		'train loss3/loss3': 0.611 'val loss3/loss3': 2.288
#                 		'loss3/top-1': 0.312 'loss3/top-5': 0.750
#
#                 7085		'train loss3/loss3': 0.880 'val loss3/loss3': 2.680
#                 		'loss3/top-1': 0.438 'loss3/top-5': 0.656
#
#                 7194		'train loss3/loss3': 0.981 'val loss3/loss3': 2.133
#                 		'loss3/top-1': 0.562 'loss3/top-5': 0.750
#
#                 7303		'train loss3/loss3': 0.662 'val loss3/loss3': 2.596
#                 		'loss3/top-1': 0.438 'loss3/top-5': 0.656
#
#                 7412		'train loss3/loss3': 0.764 'val loss3/loss3': 2.641
#                 		'loss3/top-1': 0.312 'loss3/top-5': 0.781
#
#                 7521		'train loss3/loss3': 0.856 'val loss3/loss3': 2.575
#                 		'loss3/top-1': 0.375 'loss3/top-5': 0.688
#
#                 7630		'train loss3/loss3': 0.625 'val loss3/loss3': 2.066
#                 		'loss3/top-1': 0.531 'loss3/top-5': 0.781
#
#                 7739		'train loss3/loss3': 0.960 'val loss3/loss3': 2.393
#                 		'loss3/top-1': 0.469 'loss3/top-5': 0.719
#
#                 7848		'train loss3/loss3': 0.971 'val loss3/loss3': 3.153
#                 		'loss3/top-1': 0.312 'loss3/top-5': 0.625
#
#                 7957		'train loss3/loss3': 0.800 'val loss3/loss3': 2.199
#                 		'loss3/top-1': 0.438 'loss3/top-5': 0.781
#
#                 8066		'train loss3/loss3': 0.802 'val loss3/loss3': 2.964
#                 		'loss3/top-1': 0.375 'loss3/top-5': 0.656
#
#                 8175		'train loss3/loss3': 0.649 'val loss3/loss3': 1.874
#                 		'loss3/top-1': 0.562 'loss3/top-5': 0.812
#
#                 8284		'train loss3/loss3': 0.869 'val loss3/loss3': 2.896
#                 		'loss3/top-1': 0.469 'loss3/top-5': 0.656
#
#                 8393		'train loss3/loss3': 0.742 'val loss3/loss3': 2.845
#                 		'loss3/top-1': 0.281 'loss3/top-5': 0.719
#
#                 8502		'train loss3/loss3': 0.668 'val loss3/loss3': 2.484
#                 		'loss3/top-1': 0.469 'loss3/top-5': 0.719
#
#                 8611		'train loss3/loss3': 0.512 'val loss3/loss3': 2.221
#                 		'loss3/top-1': 0.531 'loss3/top-5': 0.781
#
#                 8720		'train loss3/loss3': 0.704 'val loss3/loss3': 2.683
#                 		'loss3/top-1': 0.406 'loss3/top-5': 0.625
#
#                 8829		'train loss3/loss3': 0.776 'val loss3/loss3': 2.521
#                 		'loss3/top-1': 0.344 'loss3/top-5': 0.750
#
#                 8938		'train loss3/loss3': 0.837 'val loss3/loss3': 2.824
#                 		'loss3/top-1': 0.438 'loss3/top-5': 0.656
#
#                 9047		'train loss3/loss3': 0.938 'val loss3/loss3': 2.858
#                 		'loss3/top-1': 0.500 'loss3/top-5': 0.688
#
#                 9156		'train loss3/loss3': 0.943 'val loss3/loss3': 2.158
#                 		'loss3/top-1': 0.438 'loss3/top-5': 0.750
#
#                 9265		'train loss3/loss3': 0.741 'val loss3/loss3': 2.893
#                 		'loss3/top-1': 0.406 'loss3/top-5': 0.656
#
#                 9374		'train loss3/loss3': 0.994 'val loss3/loss3': 2.293
#                 		'loss3/top-1': 0.344 'loss3/top-5': 0.781
#
#                 9483		'train loss3/loss3': 0.884 'val loss3/loss3': 2.900
#                 		'loss3/top-1': 0.469 'loss3/top-5': 0.656
#
#                 9592		'train loss3/loss3': 0.578 'val loss3/loss3': 2.050
#                 		'loss3/top-1': 0.500 'loss3/top-5': 0.781
#
#                 9701		'train loss3/loss3': 0.858 'val loss3/loss3': 2.609
#                 		'loss3/top-1': 0.375 'loss3/top-5': 0.688
#
#                 9810		'train loss3/loss3': 0.809 'val loss3/loss3': 2.615
#                 		'loss3/top-1': 0.312 'loss3/top-5': 0.750
#
#                 9919		'train loss3/loss3': 0.818 'val loss3/loss3': 2.510
#                 		'loss3/top-1': 0.500 'loss3/top-5': 0.688
#
#                 10028		'train loss3/loss3': 0.925 'val loss3/loss3': 2.286
#                 		'loss3/top-1': 0.531 'loss3/top-5': 0.750
#
#                 10137		'train loss3/loss3': 0.704 'val loss3/loss3': 2.694
#                 		'loss3/top-1': 0.406 'loss3/top-5': 0.688
#
#                 10246		'train loss3/loss3': 0.722 'val loss3/loss3': 2.887
#                 		'loss3/top-1': 0.281 'loss3/top-5': 0.688
#
#                 10355		'train loss3/loss3': 0.758 'val loss3/loss3': 2.132
#                 		'loss3/top-1': 0.438 'loss3/top-5': 0.750
#
#                 10464		'train loss3/loss3': 0.731 'val loss3/loss3': 3.002
#                 		'loss3/top-1': 0.438 'loss3/top-5': 0.656
#
#                 10573		'train loss3/loss3': 0.505 'val loss3/loss3': 2.162
#                 		'loss3/top-1': 0.438 'loss3/top-5': 0.750
#
#                 10682		'train loss3/loss3': 1.065 'val loss3/loss3': 3.012
#                 		'loss3/top-1': 0.438 'loss3/top-5': 0.625
#
#                 10791		'train loss3/loss3': 0.730 'val loss3/loss3': 2.483
#                 		'loss3/top-1': 0.281 'loss3/top-5': 0.750
#
#                 10900		'train loss3/loss3': 0.891 'val loss3/loss3': 2.640
#                 		'loss3/top-1': 0.500 'loss3/top-5': 0.688
#
#                 11009		'train loss3/loss3': 0.846 'val loss3/loss3': 2.326
#                 		'loss3/top-1': 0.500 'loss3/top-5': 0.719
#
#                 11118		'train loss3/loss3': 0.645 'val loss3/loss3': 2.716
#                 		'loss3/top-1': 0.375 'loss3/top-5': 0.625
#
#                 11227		'train loss3/loss3': 0.922 'val loss3/loss3': 2.580
#                 		'loss3/top-1': 0.344 'loss3/top-5': 0.781
#
#                 11336		'train loss3/loss3': 0.680 'val loss3/loss3': 2.821
#                 		'loss3/top-1': 0.438 'loss3/top-5': 0.656
#
#                 11445		'train loss3/loss3': 0.751 'val loss3/loss3': 2.107
#                 		'loss3/top-1': 0.531 'loss3/top-5': 0.781
#
#                 11554		'train loss3/loss3': 0.603 'val loss3/loss3': 2.204
#                 		'loss3/top-1': 0.438 'loss3/top-5': 0.750
#
#                 11663		'train loss3/loss3': 0.659 'val loss3/loss3': 3.062
#                 		'loss3/top-1': 0.344 'loss3/top-5': 0.656
#
#                 11772		'train loss3/loss3': 0.766 'val loss3/loss3': 2.262
#                 		'loss3/top-1': 0.406 'loss3/top-5': 0.750
#
#                 11881		'train loss3/loss3': 0.854 'val loss3/loss3': 2.942
#                 		'loss3/top-1': 0.438 'loss3/top-5': 0.656
#
#                 11990		'train loss3/loss3': 0.898 'val loss3/loss3': 1.997
#                 		'loss3/top-1': 0.469 'loss3/top-5': 0.781
#
#                 12099		'train loss3/loss3': 0.811 'val loss3/loss3': 2.997
#                 		'loss3/top-1': 0.406 'loss3/top-5': 0.625
#
#                 12208		'train loss3/loss3': 0.715 'val loss3/loss3': 2.815
#                 		'loss3/top-1': 0.281 'loss3/top-5': 0.719
#
#                 12317		'train loss3/loss3': 0.893 'val loss3/loss3': 2.722
#                 		'loss3/top-1': 0.469 'loss3/top-5': 0.688
#
#                 12426		'train loss3/loss3': 0.536 'val loss3/loss3': 2.368
#                 		'loss3/top-1': 0.500 'loss3/top-5': 0.750
#
#                 12535		'train loss3/loss3': 1.031 'val loss3/loss3': 2.573
#                 		'loss3/top-1': 0.406 'loss3/top-5': 0.656
#
#                 12644		'train loss3/loss3': 0.856 'val loss3/loss3': 2.613
#                 		'loss3/top-1': 0.312 'loss3/top-5': 0.719
#
#                 12753		'train loss3/loss3': 0.468 'val loss3/loss3': 2.548
#                 		'loss3/top-1': 0.469 'loss3/top-5': 0.688
#
#                 12862		'train loss3/loss3': 0.972 'val loss3/loss3': 2.843
#                 		'loss3/top-1': 0.500 'loss3/top-5': 0.688
#
#                 12971		'train loss3/loss3': 0.846 'val loss3/loss3': 2.158
#                 		'loss3/top-1': 0.438 'loss3/top-5': 0.750
#
#                 13080		'train loss3/loss3': 0.833 'val loss3/loss3': 2.859
#                 		'loss3/top-1': 0.438 'loss3/top-5': 0.656
# Traning done in 5465 s
